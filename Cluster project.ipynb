# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import matplotlib.cm as cm
# %matplotlib inline
from sklearn import preprocessing
from subprocess import check_output

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df = df.drop('id', axis = 1)
df = df.drop('Unnamed: 32', axis = 1)
#Mapping Malignant to 1
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
#data scalling
data = pd.DataFrame(preprocessing.scale(df.iloc[:,1:32]))
data.columns = list(df.iloc[ : ,1:32].columns)
data['diagnosis'] = df['diagnosis']

drop_data = data.drop('diagnosis', axis = 1)
X = drop_data.values
#2d visualization
from sklearn.manifold import TSNE
tsne = TSNE(verbose=1, perplexity=40, n_iter= 4000)
Y = tsne.fit_transform(X)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 569 samples in 0.000s...
# [t-SNE] Computed neighbors for 569 samples in 0.031s...
# [t-SNE] Computed conditional probabilities for sample 569 / 569
# [t-SNE] Mean sigma: 1.522404
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.172325
# [t-SNE] KL divergence after 2600 iterations: 0.879306

# %%
# Cluster using KMeans
from sklearn.cluster import KMeans
kmns = KMeans(n_clusters = 2, init = "k-means++", n_init = 10, max_iter=300, tol=0.0001)
kY1 = kmns.fit_predict(X)

f, (ax1, ax2) = plt.subplots(1, 2, sharey = True)

ax1.scatter(Y[:,0],Y[:,1],  c=kY1, cmap = "jet", edgecolor = "None", alpha=0.35)
ax1.set_title('k-means clustering plot')

ax2.scatter(Y[:,0],Y[:,1],  c = data['diagnosis'], cmap = "jet", edgecolor = "None", alpha=0.35)
ax2.set_title('Actual clusters')
# Out:
# Text(0.5, 1.0, 'Actual clusters')

# %%
# Cluster using hierarchical clustering
from sklearn.cluster import AgglomerativeClustering
aggC = AgglomerativeClustering(n_clusters=2, linkage='ward')
kY2 = aggC.fit_predict(X)


f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)


ax1.scatter(Y[:,0],Y[:,1],  c=kY2, cmap = "jet", edgecolor = "None", alpha=0.35)
ax1.set_title('Hierarchical clustering plot')

ax2.scatter(Y[:,0],Y[:,1],  c = data['diagnosis'], cmap = "jet", edgecolor = "None", alpha=0.35)
ax2.set_title('Actual clusters')
# Out:
# Text(0.5, 1.0, 'Actual clusters')

# %%
#classification comparison 
from sklearn import metrics
print('KMeans: ARI =', metrics.adjusted_rand_score(data['diagnosis'], kY1))
print('Agglomerative CLustering: ARI =', 
      metrics.adjusted_rand_score(data['diagnosis'], kY2))
# Out:
# KMeans: ARI = 0.6707206476880808
# Agglomerative CLustering: ARI = 0.5750409366326297
